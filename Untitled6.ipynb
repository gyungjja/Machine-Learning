# %%
import os
import tarfile
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas.plotting import scatter_matrix
from sklearn.model_selection import train_test_split

DOWNLOAD_ROOT = "https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data"
HOUSING_PATH = os.path.join("datasets","housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/sample_submission.csv.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
        
    tgz_path = os.path.join(housing_path, "sample_submission.csv.gz")
    if not os.path.isfile(tgz_path):
        urllib.request.urlretrieve(housing_url, tgz_path)      
        sample_submission.csv.tgz=tarfile.open(tgz_path)
        sample_submission.csv.tgz.extractall(path=housing_path)
        sample_submission.csv.tgz.close()
        
def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "sample_submission.csv")
    return pd.read_csv(csv_path)

def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

if __name__=="__main__":
    fetch_housing_data()
    housing = load_housing_data()
    #housing.hist(bins=50,figsize=(10,5))
    #train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)
    #train_copy = train_set.copy()
    #ax = train_copy.plot(kind="scatter",x="Id",y="SalePrice",alpha=0.1)
    #plt.show()
    #corr_matrix = train_copy.corr()
    #attribues = ["Id","SalePrice"]
    #scatter_matrix(train_copy[attribues], figsize=(15,15))
    #print(corr_matrix["Id"].sort_values(ascending=False))
    print(housing.head())
    #print(housing.info())
    #print(housing.describe())
    #print(housing["SalePrice"].value_counts())
    #print(housing["SalePrice"].value_counts())
    print(len(train_set), "train +", len(test_set), "test")
    #plt.show()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3d84ac02da43> in <module>()
#      51     #print(housing["SalePrice"].value_counts())
#      52     #print(housing["SalePrice"].value_counts())
# ---> 53     print(len(train_set), "train +", len(test_set), "test")
#      54     #plt.show()
#
# NameError: name 'train_set' is not defined

# %%
import matplotlib.pyplot as plt
housing.hist(bins=50,figsize=(10,5))
plt.show()

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)
print(len(train_set), "train +", len(test_set), "test")
# Out:
# 1167 train + 292 test

# %%
ax = train_copy.plot(kind="scatter",x="Id",y="SalePrice",alpha=0.1)
plt.show()

# %%
corr_matrix = train_copy.corr()
print(corr_matrix["Id"].sort_values(ascending=False))
# Out:
# Id           1.000000
# SalePrice    0.126885
# Name: Id, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attribues = ["Id","SalePrice"]
scatter_matrix(train_copy[attribues], figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000120BD828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012056BE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000011FBC2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011F93940>]],
#       dtype=object)

# %%
print(housing.isnull().sum())
print(housing.isnull().sum() / len(housing)) #결측치 missing value 확인
# Out:
# Id           0
# SalePrice    0
# dtype: int64
# Id           0.0
# SalePrice    0.0
# dtype: float64
